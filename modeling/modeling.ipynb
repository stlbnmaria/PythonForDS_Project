# %%
from jours_feries_france import JoursFeries
import os
import pandas as pd
from pathlib import Path
import re
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, StandardScaler
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import make_pipeline

from vacances_scolaires_france import SchoolHolidayDates

# %%
if os.getcwd().split("/")[-1] == "modeling":
    os.chdir(os.path.join(os.getcwd(), '..'))

import problem

# %% [markdown]
# ## Load data

# %%
X_train, y_train = problem.get_train_data()
X_test, y_test = problem.get_test_data()

# %% [markdown]
# ## Functions for adding more variables

# %%
def _encode_dates(X, last_step: bool=True):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X.loc[:, "year"] = X["date"].dt.year
    X.loc[:, "month"] = X["date"].dt.month
    X.loc[:, "day"] = X["date"].dt.day
    X.loc[:, "weekday"] = X["date"].dt.weekday
    X.loc[:, "hour"] = X["date"].dt.hour

    if last_step: 
        # Finally we can drop the original columns from the dataframe
        return X.drop(columns=["date"])
    else:
        return X

# %%
def _additional_date_variables(X, last_step: bool=True):
    X = X.copy()  # modify a copy of X

    # add seasons
    seasons = {1: "winter", 2: "winter", 3: "spring", 4: "spring", 
               5: "spring", 6: "summer", 7: "summer", 8: "summer", 
               9: "autumn", 10: "autumn", 11: "autumn", 12: "winter"}
    X.loc[:, "season"] = X["date"].dt.month.map(seasons)

    public_holidays = []
    school_holidays = {}
    for year in X["date"].dt.year.unique():
        public_holidays.extend(JoursFeries.for_year(year).values())
        school_holidays.update(SchoolHolidayDates().holidays_for_year_and_zone(year, 'C'))
    
    # add public holidays
    X.loc[:, "public_holiday"] = X["date"].isin(public_holidays)

    # add school holidays names
    # school_holidays_name = {k: re.sub("\s+|'", '_', 
    #                                   re.sub('[éë]', 'e', v['nom_vacances'].lower())) 
    #                         for k, v in school_holidays.items() if v['vacances_zone_c']}
    # X.loc[:, "school_holiday_name"] = X["date"].map(school_holidays_name)

    # add school holidays
    school_holidays_bool = [k for k,v in school_holidays.items() if v['vacances_zone_c']]
    X.loc[:, "school_holiday"] = X["date"].isin(school_holidays_bool)

    if last_step: 
        # Finally we can drop the original columns from the dataframe
        return X.drop(columns=["date"])
    else:
        return X

# %% [markdown]
# ## Linear Model

# %%
date_encoder = FunctionTransformer(_encode_dates, kw_args={"last_step": True})
date_cols = _encode_dates(X_train[["date"]]).columns.tolist()

categorical_encoder = OneHotEncoder(handle_unknown="ignore")
categorical_cols = ["counter_name", "site_name"]

preprocessor = ColumnTransformer(
    [
        ("date", OneHotEncoder(handle_unknown="ignore"), date_cols),
        ("cat", categorical_encoder, categorical_cols),
    ]
)

regressor = Ridge()

pipe = make_pipeline(date_encoder, preprocessor, regressor)
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('functiontransformer',
#                  FunctionTransformer(func=<function _encode_dates at 0x7fc9e11f09d0>,
#                                      kw_args={'last_step': True})),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('date',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['year', 'month', 'day',
#                                                    'weekday', 'hour']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['counter_name',
#                                                    'site_name'])])),
#                 ('ridge', Ridge())])

# %%
print(
    f"Train set, RMSE={mean_squared_error(y_train, pipe.predict(X_train), squared=False):.2f}"
)
print(
    f"Test set, RMSE={mean_squared_error(y_test, pipe.predict(X_test), squared=False):.2f}"
)
# Out:
# Train set, RMSE=0.80
# Test set, RMSE=0.73

# %%
date_encoder = FunctionTransformer(_encode_dates, kw_args={"last_step": False})
date_cols = ["year", "month", "day", "weekday", "hour"]

add_date_encoder = FunctionTransformer(_additional_date_variables, kw_args={"last_step": True})
add_date_cols = ["season"]

categorical_encoder = OneHotEncoder(handle_unknown="ignore")
categorical_cols = ["counter_name", "site_name"]

preprocessor = ColumnTransformer(
    [
        ("date", OneHotEncoder(handle_unknown="ignore"), date_cols),
        ("add_date", OneHotEncoder(handle_unknown="ignore"), add_date_cols),
        ("cat", categorical_encoder, categorical_cols),
    ]
)

regressor = Ridge()

pipe = make_pipeline(date_encoder, add_date_encoder, preprocessor, regressor)
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('functiontransformer-1',
#                  FunctionTransformer(func=<function _encode_dates at 0x7fc9e11f09d0>,
#                                      kw_args={'last_step': False})),
#                 ('functiontransformer-2',
#                  FunctionTransformer(func=<function _additional_date_variables at 0x7fc9e11f0b80>,
#                                      kw_args={'last_step': True})),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('date',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['year', 'month', 'day',
#                                                    'weekday', 'hour']),
#                                                  ('add_date',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['season']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['counter_name',
#                                                    'site_name'])])),
#                 ('ridge', Ridge())])

# %%
print(
    f"Train set, RMSE={mean_squared_error(y_train, pipe.predict(X_train), squared=False):.2f}"
)
print(
    f"Test set, RMSE={mean_squared_error(y_test, pipe.predict(X_test), squared=False):.2f}"
)
# Out:
# Train set, RMSE=0.80
# Test set, RMSE=0.72

# %% [markdown]
# ## Tree Models

# %%
date_encoder = FunctionTransformer(_encode_dates, kw_args={"last_step": False})
date_cols = ["year", "month", "day", "weekday", "hour"]

add_date_encoder = FunctionTransformer(_additional_date_variables, kw_args={"last_step": True})
add_date_cols = ["season"]

categorical_encoder = OneHotEncoder(handle_unknown="ignore")
categorical_cols = ["counter_name", "site_name"]

preprocessor = ColumnTransformer(
    [
        ("date", OneHotEncoder(handle_unknown="ignore"), date_cols),
        ("add_date", OneHotEncoder(handle_unknown="ignore"), add_date_cols),
        ("cat", categorical_encoder, categorical_cols),
    ]
)

regressor = RandomForestRegressor(max_features="sqrt", verbose=100, n_jobs=4)

pipe = make_pipeline(date_encoder, add_date_encoder, preprocessor, regressor)
pipe.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100[Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:   26.5s
#
# building tree 6 of 100[Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:   28.6s
#
# building tree 7 of 100[Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:   29.0s
#
# building tree 8 of 100[Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:   29.5s
#
# building tree 9 of 100[Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:   50.2s
#
# building tree 10 of 100[Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:   53.1s
#
# building tree 11 of 100[Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:   53.3s
#
# building tree 12 of 100[Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:   54.6s
#
# building tree 13 of 100[Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:  1.3min
#
# building tree 14 of 100[Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:  1.3min
#
# building tree 15 of 100[Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:  1.3min
#
# building tree 16 of 100[Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:  1.3min
#
# building tree 17 of 100[Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:  1.6min
#
# building tree 18 of 100[Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:  1.7min
#
# building tree 19 of 100[Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:  1.7min
#
# building tree 20 of 100[Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:  1.7min
#
# building tree 21 of 100[Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:  2.0min
#
# building tree 22 of 100[Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:  2.1min
#
# building tree 23 of 100[Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:  2.1min
#
# building tree 24 of 100[Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:  2.1min
#
# building tree 25 of 100[Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:  2.4min
#
# building tree 26 of 100[Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:  2.5min
#
# building tree 27 of 100
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:  2.5min
# building tree 28 of 100[Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:  2.5min
#
# building tree 29 of 100[Parallel(n_jobs=4)]: Done  25 tasks      | elapsed:  2.8min
#
# building tree 30 of 100[Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:  2.9min
#
# building tree 31 of 100[Parallel(n_jobs=4)]: Done  27 tasks      | elapsed:  2.9min
#
# building tree 32 of 100[Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:  3.0min
#
# building tree 33 of 100[Parallel(n_jobs=4)]: Done  29 tasks      | elapsed:  3.2min
#
# building tree 34 of 100[Parallel(n_jobs=4)]: Done  30 tasks      | elapsed:  3.3min
#
# building tree 35 of 100[Parallel(n_jobs=4)]: Done  31 tasks      | elapsed:  3.3min
#
# building tree 36 of 100[Parallel(n_jobs=4)]: Done  32 tasks      | elapsed:  3.4min
#
# building tree 37 of 100[Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:  3.6min
#
# building tree 38 of 100[Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:  3.7min
#
# building tree 39 of 100[Parallel(n_jobs=4)]: Done  35 tasks      | elapsed:  3.7min
#
# building tree 40 of 100[Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:  3.7min
#
# building tree 41 of 100[Parallel(n_jobs=4)]: Done  37 tasks      | elapsed:  4.0min
#
# building tree 42 of 100[Parallel(n_jobs=4)]: Done  38 tasks      | elapsed:  4.1min
#
# building tree 43 of 100[Parallel(n_jobs=4)]: Done  39 tasks      | elapsed:  4.1min
#
# building tree 44 of 100[Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:  4.1min
#
# building tree 45 of 100[Parallel(n_jobs=4)]: Done  41 tasks      | elapsed:  4.4min
#
# building tree 46 of 100[Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:  4.5min
#
# building tree 47 of 100[Parallel(n_jobs=4)]: Done  43 tasks      | elapsed:  4.5min
#
# building tree 48 of 100[Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:  4.5min
#
# building tree 49 of 100[Parallel(n_jobs=4)]: Done  45 tasks      | elapsed:  4.8min
#
# building tree 50 of 100[Parallel(n_jobs=4)]: Done  46 tasks      | elapsed:  4.8min
#
# building tree 51 of 100[Parallel(n_jobs=4)]: Done  47 tasks      | elapsed:  4.9min
#
# building tree 52 of 100[Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:  4.9min
#
# building tree 53 of 100[Parallel(n_jobs=4)]: Done  49 tasks      | elapsed:  5.2min
#
# building tree 54 of 100[Parallel(n_jobs=4)]: Done  50 tasks      | elapsed:  5.3min
#
# building tree 55 of 100[Parallel(n_jobs=4)]: Done  51 tasks      | elapsed:  5.3min
#
# building tree 56 of 100[Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:  5.3min
#
# building tree 57 of 100[Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:  5.6min
#
# building tree 58 of 100[Parallel(n_jobs=4)]: Done  54 tasks      | elapsed:  5.6min
#
# building tree 59 of 100[Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:  5.7min
#
# building tree 60 of 100[Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:  5.7min
#
# building tree 61 of 100[Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:  6.0min
#
# building tree 62 of 100[Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:  6.0min
#
# building tree 63 of 100[Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:  6.1min
#
# building tree 64 of 100[Parallel(n_jobs=4)]: Done  60 tasks      | elapsed:  6.1min
#
# building tree 65 of 100[Parallel(n_jobs=4)]: Done  61 tasks      | elapsed:  6.4min
#
# building tree 66 of 100[Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:  6.4min
#
# building tree 67 of 100[Parallel(n_jobs=4)]: Done  63 tasks      | elapsed:  6.5min
#
# building tree 68 of 100[Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:  6.5min
#
# building tree 69 of 100[Parallel(n_jobs=4)]: Done  65 tasks      | elapsed:  6.8min
#
# building tree 70 of 100[Parallel(n_jobs=4)]: Done  66 tasks      | elapsed:  6.8min
#
# building tree 71 of 100[Parallel(n_jobs=4)]: Done  67 tasks      | elapsed:  6.9min
#
# building tree 72 of 100[Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:  6.9min
#
# building tree 73 of 100[Parallel(n_jobs=4)]: Done  69 tasks      | elapsed:  7.2min
#
# building tree 74 of 100[Parallel(n_jobs=4)]: Done  70 tasks      | elapsed:  7.2min
#
# building tree 75 of 100[Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:  7.3min
#
# building tree 76 of 100[Parallel(n_jobs=4)]: Done  72 tasks      | elapsed:  7.3min
#
# building tree 77 of 100[Parallel(n_jobs=4)]: Done  73 tasks      | elapsed:  7.6min
#
# building tree 78 of 100[Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:  7.6min
#
# building tree 79 of 100[Parallel(n_jobs=4)]: Done  75 tasks      | elapsed:  7.7min
#
# building tree 80 of 100
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:  7.7min
# building tree 81 of 100[Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:  8.0min
#
# building tree 82 of 100[Parallel(n_jobs=4)]: Done  78 tasks      | elapsed:  8.0min
#
# building tree 83 of 100[Parallel(n_jobs=4)]: Done  79 tasks      | elapsed:  8.1min
#
# building tree 84 of 100
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:  8.1min
# building tree 85 of 100[Parallel(n_jobs=4)]: Done  81 tasks      | elapsed:  8.4min
#
# building tree 86 of 100[Parallel(n_jobs=4)]: Done  82 tasks      | elapsed:  8.4min
#
# building tree 87 of 100[Parallel(n_jobs=4)]: Done  83 tasks      | elapsed:  8.5min
#
# building tree 88 of 100[Parallel(n_jobs=4)]: Done  84 tasks      | elapsed:  8.5min
#
# building tree 89 of 100[Parallel(n_jobs=4)]: Done  85 tasks      | elapsed:  8.8min
#
# building tree 90 of 100[Parallel(n_jobs=4)]: Done  86 tasks      | elapsed:  8.8min
#
# building tree 91 of 100[Parallel(n_jobs=4)]: Done  87 tasks      | elapsed:  8.9min
#
# building tree 92 of 100[Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:  8.9min
#
# building tree 93 of 100[Parallel(n_jobs=4)]: Done  89 tasks      | elapsed:  9.2min
#
# building tree 94 of 100[Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:  9.2min
#
# building tree 95 of 100[Parallel(n_jobs=4)]: Done  91 tasks      | elapsed:  9.3min
#
# building tree 96 of 100
# [Parallel(n_jobs=4)]: Done  92 tasks      | elapsed:  9.3min
# building tree 97 of 100[Parallel(n_jobs=4)]: Done  93 tasks      | elapsed:  9.6min
#
# building tree 98 of 100
# building tree 99 of 100[Parallel(n_jobs=4)]: Done  95 out of 100 | elapsed:  9.7min remaining:   30.6s
#
# building tree 100 of 100
# [Parallel(n_jobs=4)]: Done  97 out of 100 | elapsed: 10.0min remaining:   18.5s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed: 10.1min finished
# Pipeline(steps=[('functiontransformer-1',
#                  FunctionTransformer(func=<function _encode_dates at 0x7fc9e11f09d0>,
#                                      kw_args={'last_step': False})),
#                 ('functiontransformer-2',
#                  FunctionTransformer(func=<function _additional_date_variables at 0x7fc9e11f0b80>,
#                                      kw_args={'last_step': True})),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('date',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['year', 'month', 'day',
#                                                    'weekday', 'hour']),
#                                                  ('add_date',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['season']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['counter_name',
#                                                    'site_name'])])),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_features='sqrt', n_jobs=4,
#                                        verbose=100))])

# %%
print(
    f"Train set, RMSE={mean_squared_error(y_train, pipe.predict(X_train), squared=False):.2f}"
)
print(
    f"Test set, RMSE={mean_squared_error(y_test, pipe.predict(X_test), squared=False):.2f}"
)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  25 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done  27 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done  29 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done  30 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done  31 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done  32 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done  35 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done  37 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  38 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  39 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  41 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  43 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  45 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done  46 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done  47 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done  49 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  50 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  51 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  54 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  60 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  61 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  63 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done  65 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  66 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  67 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  69 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  70 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  72 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  73 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done  75 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done  78 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done  79 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done  81 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done  82 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done  83 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done  84 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done  85 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done  86 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done  87 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done  89 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done  91 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done  92 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done  93 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done  95 out of 100 | elapsed:    3.1s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done  97 out of 100 | elapsed:    3.2s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    3.2s finished
# Train set, RMSE=0.17
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  25 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  27 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  29 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  30 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  31 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  32 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  35 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  38 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  50 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  51 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  54 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  60 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  61 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  63 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  65 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  66 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  67 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  69 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  70 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  72 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  73 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  75 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  78 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  79 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  81 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  82 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  83 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  84 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  85 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  86 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  87 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  89 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  91 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  92 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  93 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  95 out of 100 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  97 out of 100 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.2s finished
# Test set, RMSE=0.45

# %%
date_encoder = FunctionTransformer(_encode_dates, kw_args={"last_step": False})
date_cols = ["year", "month", "day", "weekday", "hour"]

add_date_encoder = FunctionTransformer(_additional_date_variables, kw_args={"last_step": True})
add_date_cols = ["season"]

categorical_encoder = OneHotEncoder(handle_unknown="ignore")
categorical_cols = ["counter_name", "site_name"]

preprocessor = ColumnTransformer(
    [
        ("date", OneHotEncoder(handle_unknown="ignore"), date_cols),
        ("add_date", OneHotEncoder(handle_unknown="ignore"), add_date_cols),
        ("cat", categorical_encoder, categorical_cols),
    ]
)

regressor = RandomForestRegressor(max_features="sqrt", verbose=100, n_jobs=4, max_samples=0.5)

pipe = make_pipeline(date_encoder, add_date_encoder, preprocessor, regressor)
pipe.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100[Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:   15.4s
#
# building tree 6 of 100
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:   15.5s
# building tree 7 of 100[Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:   16.0s
#
# building tree 8 of 100
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:   16.0s
# building tree 9 of 100[Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:   31.0s
#
# building tree 10 of 100[Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:   31.6s
#
# building tree 11 of 100
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:   31.8s
# building tree 12 of 100
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:   31.8s
# building tree 13 of 100[Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:   46.5s
#
# building tree 14 of 100[Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:   46.7s
#
# building tree 15 of 100
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:   47.3s
# building tree 16 of 100
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:   47.5s
# building tree 17 of 100[Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:  1.0min
#
# building tree 18 of 100
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:  1.0min
# building tree 19 of 100[Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:  1.1min
#
# building tree 20 of 100
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:  1.1min
# building tree 21 of 100[Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:  1.3min
#
# building tree 22 of 100
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:  1.3min
# building tree 23 of 100[Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:  1.3min
#
# building tree 24 of 100[Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:  1.3min
#
# building tree 25 of 100[Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:  1.6min
#
# building tree 26 of 100[Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:  1.6min
#
# building tree 27 of 100
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:  1.6min
# building tree 28 of 100[Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:  1.6min
#
# building tree 29 of 100[Parallel(n_jobs=4)]: Done  25 tasks      | elapsed:  1.8min
#
# building tree 30 of 100[Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:  1.8min
#
# building tree 31 of 100[Parallel(n_jobs=4)]: Done  27 tasks      | elapsed:  1.8min
#
# building tree 32 of 100[Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:  1.8min
#
# building tree 33 of 100[Parallel(n_jobs=4)]: Done  29 tasks      | elapsed:  2.1min
#
# building tree 34 of 100[Parallel(n_jobs=4)]: Done  30 tasks      | elapsed:  2.1min
#
# building tree 35 of 100[Parallel(n_jobs=4)]: Done  31 tasks      | elapsed:  2.1min
#
# building tree 36 of 100[Parallel(n_jobs=4)]: Done  32 tasks      | elapsed:  2.1min
#
# building tree 37 of 100[Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:  2.4min
#
# building tree 38 of 100
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:  2.4min
# building tree 39 of 100[Parallel(n_jobs=4)]: Done  35 tasks      | elapsed:  2.4min
#
# building tree 40 of 100[Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:  2.4min
#
# building tree 41 of 100[Parallel(n_jobs=4)]: Done  37 tasks      | elapsed:  2.6min
#
# building tree 42 of 100[Parallel(n_jobs=4)]: Done  38 tasks      | elapsed:  2.6min
#
# building tree 43 of 100
# [Parallel(n_jobs=4)]: Done  39 tasks      | elapsed:  2.6min
# building tree 44 of 100
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:  2.6min
# building tree 45 of 100[Parallel(n_jobs=4)]: Done  41 tasks      | elapsed:  2.9min
#
# building tree 46 of 100[Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:  2.9min
#
# building tree 47 of 100[Parallel(n_jobs=4)]: Done  43 tasks      | elapsed:  2.9min
#
# building tree 48 of 100[Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:  2.9min
#
# building tree 49 of 100[Parallel(n_jobs=4)]: Done  45 tasks      | elapsed:  3.1min
#
# building tree 50 of 100[Parallel(n_jobs=4)]: Done  46 tasks      | elapsed:  3.1min
#
# building tree 51 of 100[Parallel(n_jobs=4)]: Done  47 tasks      | elapsed:  3.2min
#
# building tree 52 of 100
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:  3.2min
# building tree 53 of 100[Parallel(n_jobs=4)]: Done  49 tasks      | elapsed:  3.4min
#
# building tree 54 of 100[Parallel(n_jobs=4)]: Done  50 tasks      | elapsed:  3.4min
#
# building tree 55 of 100[Parallel(n_jobs=4)]: Done  51 tasks      | elapsed:  3.4min
#
# building tree 56 of 100
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:  3.4min
# building tree 57 of 100[Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:  3.6min
#
# building tree 58 of 100[Parallel(n_jobs=4)]: Done  54 tasks      | elapsed:  3.7min
#
# building tree 59 of 100[Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:  3.7min
#
# building tree 60 of 100[Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:  3.7min
#
# building tree 61 of 100[Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:  3.9min
#
# building tree 62 of 100[Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:  3.9min
#
# building tree 63 of 100[Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:  3.9min
#
# building tree 64 of 100[Parallel(n_jobs=4)]: Done  60 tasks      | elapsed:  4.0min
#
# building tree 65 of 100[Parallel(n_jobs=4)]: Done  61 tasks      | elapsed:  4.2min
#
# building tree 66 of 100[Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:  4.2min
#
# building tree 67 of 100
# [Parallel(n_jobs=4)]: Done  63 tasks      | elapsed:  4.2min
# building tree 68 of 100[Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:  4.2min
#
# building tree 69 of 100[Parallel(n_jobs=4)]: Done  65 tasks      | elapsed:  4.4min
#
# building tree 70 of 100[Parallel(n_jobs=4)]: Done  66 tasks      | elapsed:  4.5min
#
# building tree 71 of 100[Parallel(n_jobs=4)]: Done  67 tasks      | elapsed:  4.5min
#
# building tree 72 of 100[Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:  4.5min
#
# building tree 73 of 100[Parallel(n_jobs=4)]: Done  69 tasks      | elapsed:  4.7min
#
# building tree 74 of 100[Parallel(n_jobs=4)]: Done  70 tasks      | elapsed:  4.7min
#
# building tree 75 of 100[Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:  4.7min
#
# building tree 76 of 100
# [Parallel(n_jobs=4)]: Done  72 tasks      | elapsed:  4.8min
# building tree 77 of 100[Parallel(n_jobs=4)]: Done  73 tasks      | elapsed:  5.0min
#
# building tree 78 of 100[Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:  5.0min
#
# building tree 79 of 100
# [Parallel(n_jobs=4)]: Done  75 tasks      | elapsed:  5.0min
# building tree 80 of 100[Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:  5.0min
#
# building tree 81 of 100[Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:  5.2min
#
# building tree 82 of 100[Parallel(n_jobs=4)]: Done  78 tasks      | elapsed:  5.3min
#
# building tree 83 of 100[Parallel(n_jobs=4)]: Done  79 tasks      | elapsed:  5.3min
#
# building tree 84 of 100
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:  5.3min
# building tree 85 of 100[Parallel(n_jobs=4)]: Done  81 tasks      | elapsed:  5.5min
#
# building tree 86 of 100[Parallel(n_jobs=4)]: Done  82 tasks      | elapsed:  5.5min
#
# building tree 87 of 100[Parallel(n_jobs=4)]: Done  83 tasks      | elapsed:  5.5min
#
# building tree 88 of 100[Parallel(n_jobs=4)]: Done  84 tasks      | elapsed:  5.5min
#
# building tree 89 of 100[Parallel(n_jobs=4)]: Done  85 tasks      | elapsed:  5.7min
#
# building tree 90 of 100[Parallel(n_jobs=4)]: Done  86 tasks      | elapsed:  5.8min
#
# building tree 91 of 100
# [Parallel(n_jobs=4)]: Done  87 tasks      | elapsed:  5.8min
# building tree 92 of 100
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:  5.8min
# building tree 93 of 100[Parallel(n_jobs=4)]: Done  89 tasks      | elapsed:  6.0min
#
# building tree 94 of 100[Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:  6.0min
#
# building tree 95 of 100
# [Parallel(n_jobs=4)]: Done  91 tasks      | elapsed:  6.0min
# building tree 96 of 100[Parallel(n_jobs=4)]: Done  92 tasks      | elapsed:  6.1min
#
# building tree 97 of 100[Parallel(n_jobs=4)]: Done  93 tasks      | elapsed:  6.3min
#
# building tree 98 of 100
# building tree 99 of 100
# [Parallel(n_jobs=4)]: Done  95 out of 100 | elapsed:  6.3min remaining:   19.9s
# building tree 100 of 100
# [Parallel(n_jobs=4)]: Done  97 out of 100 | elapsed:  6.5min remaining:   12.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:  6.6min finished
# Pipeline(steps=[('functiontransformer-1',
#                  FunctionTransformer(func=<function _encode_dates at 0x7fc9e11f09d0>,
#                                      kw_args={'last_step': False})),
#                 ('functiontransformer-2',
#                  FunctionTransformer(func=<function _additional_date_variables at 0x7fc9e11f0b80>,
#                                      kw_args={'last_step': True})),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('date',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['year', 'month', 'day',
#                                                    'weekday', 'hour']),
#                                                  ('add_date',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['season']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['counter_name',
#                                                    'site_name'])])),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_features='sqrt', max_samples=0.5,
#                                        n_jobs=4, verbose=100))])

# %%
print(
    f"Train set, RMSE={mean_squared_error(y_train, pipe.predict(X_train), squared=False):.2f}"
)
print(
    f"Test set, RMSE={mean_squared_error(y_test, pipe.predict(X_test), squared=False):.2f}"
)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  25 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  29 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  30 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  31 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  32 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done  35 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done  37 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done  38 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done  39 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done  41 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done  43 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done  45 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done  46 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done  47 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  49 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  50 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  51 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done  54 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done  60 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done  61 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  63 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  65 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  66 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  67 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done  69 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  70 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  72 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  73 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  75 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done  78 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done  79 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done  81 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  82 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  83 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  84 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done  85 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  86 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  87 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done  89 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done  91 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done  92 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done  93 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done  95 out of 100 | elapsed:    2.5s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done  97 out of 100 | elapsed:    2.6s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    2.6s finished
# Train set, RMSE=0.28
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  25 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  27 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  29 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  30 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  31 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  32 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  35 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  37 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  38 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  41 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  43 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  45 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  46 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  47 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  50 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  51 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  54 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  60 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  61 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  63 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  65 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  66 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  67 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  69 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  70 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  72 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  73 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  75 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  78 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  79 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  81 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  82 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  83 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  84 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  85 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  86 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  87 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  89 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  91 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  92 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  93 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  95 out of 100 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  97 out of 100 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.2s finished
# Test set, RMSE=0.45
